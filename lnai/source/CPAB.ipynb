# %%
from cpab import TestConfiguration, plot_coaching_evaluation_results

setting = TestConfiguration(max_n=12, n_timesteps=2_000_000)
setting.run()
#setting.load('cpab_N12_T1000000_SR0.9.zip')
setting.evaluate_agent()
plot_coaching_evaluation_results({'PPO + Coaching': setting.results})
# Out:
# Using cpu device
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 5106     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.76     |
# | time/              |          |
# |    fps             | 3215     |
# |    iterations      | 2        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 16384    |
# | train/             |          |
# |    learning_rate   | 0.0003   |
# ---------------------------------
#
# [CURRICULUM ADVANCED] Advanced Max Stage to N = 3 (SR: 90.0%)
#
# ---------------------------------
# | rollout/           |          |
# |    success_rate    | 0.4      |
# | time/              |          |
# |    fps             | 2704     |
# ...
